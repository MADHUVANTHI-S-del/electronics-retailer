# %% [markdown]
# # Return Insight: 02 - Data Cleaning Pipeline
# Cleans raw datasets, removes duplicates, handles missing values, and formats dates.

# %%
from src.data.clean_data import clean_all
clean_all()
