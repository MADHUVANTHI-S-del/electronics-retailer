# %% [markdown]
# # Return Insight: 07 - Normal vs Disruption Operational Experiment
# Analyzes return metrics across NORMAL, CAPACITY_LOSS, DELIVERY_DELAY, and URGENT_DEMAND operational scenarios.

# %%
import pandas as pd
exp_df = pd.read_csv('../reports/normal_vs_disruption.csv')
exp_df
