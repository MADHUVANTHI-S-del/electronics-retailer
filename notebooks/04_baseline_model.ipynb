# %% [markdown]
# # Return Insight: 04 - Baseline Keyword Classifier
# Evaluates Model 1: Rule & Keyword Baseline classifier.

# %%
import pandas as pd
from src.models.baseline import KeywordBaselineClassifier
val_df = pd.read_csv('../data/processed/validation.csv')
clf = KeywordBaselineClassifier()
preds = clf.predict(val_df['return_text'])
print('Baseline Sample Predictions:', preds[:5])
