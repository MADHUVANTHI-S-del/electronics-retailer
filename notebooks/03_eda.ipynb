# %% [markdown]
# # Return Insight: 03 - Exploratory Data Analysis (EDA)
# Analyzes return reasons, preventable percentages, category volumes, and financial impact.

# %%
import pandas as pd
master_df = pd.read_csv('../data/cleaned/master_returns_dataset.csv')
print(master_df['ground_truth_reason'].value_counts())
print(master_df.groupby('product_category')['refund_amount'].sum())
