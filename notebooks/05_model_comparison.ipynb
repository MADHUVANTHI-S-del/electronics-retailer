# %% [markdown]
# # Return Insight: 05 - Model Comparison & Selection
# Compares 6 candidate models (Baseline, TF-IDF LogReg, SVM, Naive Bayes, Random Forest, Combined Classifier).

# %%
import pandas as pd
comp_df = pd.read_csv('../reports/model_comparison.csv')
comp_df
