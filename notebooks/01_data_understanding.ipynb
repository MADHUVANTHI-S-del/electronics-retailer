# %% [markdown]
# # Return Insight: 01 - Data Understanding
# This notebook inspects the synthetic raw datasets for Return Insight.

# %%
import pandas as pd
from pathlib import Path

raw_dir = Path('../data/raw')
returns_raw = pd.read_csv(raw_dir / 'returns_raw.csv')
print('Returns shape:', returns_raw.shape)
returns_raw.head()
