# %% [markdown]
# # Return Insight: 06 - Error Analysis (False Positives & False Negatives)
# Analyzes confusion pairs, ambiguous return text cases, and physical inspection conflicts.

# %%
import pandas as pd
from src.analysis.false_positive_analysis import analyze_false_positives
test_df = pd.read_csv('../data/processed/test.csv')
print('Test dataset shape:', test_df.shape)
